# %%
# !git clone https://github.com/BillPapakyriakou/Thesis_NLP.git
# %cd Thesis_NLP
# Out:
# fatal: destination path 'Thesis_NLP' already exists and is not an empty directory.
# /content/Thesis_NLP

# %%
# !pip install -e ".[dev]"
# Out:
# Obtaining file:///content/Thesis_NLP
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for Thesis_NLP (pyproject.toml) ... done
#   Created wheel for Thesis_NLP: filename=thesis_nlp-0.2.0-0.editable-py3-none-any.whl size=1440 sha256=e1e2d65711b5baae66dfa9ad6c3eb51e25a8be8dd992729d8e90528b9484e6cd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rbw363fp/wheels/59/2a/1d/db4f198765abb030495bdface7c3b216d4a255ac4e8091d0d0
# Successfully built Thesis_NLP
# ...
#   Attempting uninstall: Thesis_NLP
#     Found existing installation: Thesis_NLP 0.2.0
#     Uninstalling Thesis_NLP-0.2.0:
#       Successfully uninstalled Thesis_NLP-0.2.0
# ...

# %%
# !python -c "import diploma_tqa; print('project import ok')"
# Out:
# project import ok

# %%
# !apt-get update
# !apt-get install -y zstd
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 https://cli.github.com/packages stable InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,646 kB]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [95.6 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,295 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,947 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [77.8 kB]
# ...

# %%
import subprocess, time

subprocess.Popen(["ollama", "serve"])
time.sleep(5)

# %%
#!ollama pull qwen2.5-coder:7b

# %%
# !ollama pull rnj-1

# %%
# !ollama list
# Out:
# NAME            ID              SIZE      MODIFIED
# rnj-1:latest    d20e29ab8d0f    5.1 GB    Less than a second ago

# %%
# !python -m diploma_tqa.scripts.run_smoke_test \
  --model rnj-1:latest \
  --lite \
  --schema-mode hint \
  --tool-mode inspect \
  --max-retries 2 \
  --output-dir results/qwen3b_lite_100_schema_hint_inspect_tool_repair2 \
  2>&1 | tee results/qwen3b_lite_100_schema_hint_inspect_tool_repair2_run_output.txt
# Out:
# tee: results/qwen3b_lite_100_schema_hint_inspect_tool_repair2_run_output.txt: No such file or directory
# ...
# Running examples:  56%|█████▌    | 291/522 [29:16<17:05,  4.44s/it, success=284/291, retried=7, dataset=074_Lift]<string>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <string>:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# ...

# %%
# !python -m diploma_tqa.scripts.analyze_logs results/qwen3b_lite_100_schema_hint_auto_tool_repair2
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/Thesis_NLP/src/diploma_tqa/scripts/analyze_logs.py", line 173, in <module>
#     main()
#   File "/content/Thesis_NLP/src/diploma_tqa/scripts/analyze_logs.py", line 67, in main
#     logs = load_jsonl(logs_path)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Thesis_NLP/src/diploma_tqa/scripts/analyze_logs.py", line 9, in load_jsonl
#     with open(path, "r", encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'results/qwen3b_lite_100_schema_hint_auto_tool_repair2/logs.jsonl'
